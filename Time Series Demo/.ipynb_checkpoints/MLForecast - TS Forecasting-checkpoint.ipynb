# %% [markdown]
# # Steps in this Notebook
#
# 1. Imports
# 2. Snowflake Setup
# 3. TS Forecasting with DARTS
# 4. Deployment of TS Forecasting with Snowflake Tasks

# %% [markdown]
# # Imports

# %%
from snowflake.snowpark.session import Session
import snowflake.snowpark.types as T
import snowflake.snowpark.functions as F
from snowflake.snowpark.functions import col

from snowflake.snowpark.functions import udf
from snowflake.snowpark.types import IntegerType, FloatType, StringType,StructType, StructField

import snowflake.ml.modeling.preprocessing as snowml
from snowflake.ml.modeling.xgboost import XGBClassifier
from snowflake.ml.modeling.preprocessing import KBinsDiscretizer, OrdinalEncoder, OneHotEncoder
from snowflake.ml.modeling.impute import SimpleImputer

import json
import os
import pandas as pd
from datetime import date, timedelta

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
connection_parameters = json.load(open('/Users/skhara/Documents/Code/creds.json'))
session = Session.builder.configs(connection_parameters).create()

# %%
import os
os.getcwd()
# Out:
# '/Users/skhara/Documents/GitHub/skhara-demos-public/Time Series Demo'

# %% [markdown]
# # Snowflake Setup: Create a Database and Schema
#
# We will be using PUBLIC schema.

# %%
session.sql('USE DATABASE TIME_SERIES').collect()
session.sql('USE SCHEMA SYNTHETIC_DATA').collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %%
# Load TS data from Store_Traffic Database into ACCRUENT_TS_FORECASTING DB for testing purposes.
sdf_raw = session.table('TIME_SERIES')

# %%
# Print the Number of Time Series/Pumps that we have to predict
session.sql('SELECT COUNT(DISTINCT SERIES_ID) FROM TIME_SERIES').collect()
# Out:
# [Row(COUNT(DISTINCT SERIES_ID)=1000)]

# %%
# Print the SERIES_ID and Start and End date of Time Series
session.sql('SELECT SERIES_ID, MIN(DATE), MAX(DATE) FROM TIME_SERIES GROUP BY SERIES_ID').collect()
# Out:
# [Row(SERIES_ID=1, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=2, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=3, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=4, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=5, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=6, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=7, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=9, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=10, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=11, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=12, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=13, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=14, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=15, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=17, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=18, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=19, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=20, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=23, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=24, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=25, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=26, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=27, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=28, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=30, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=38, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=39, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=40, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=41, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=42, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=47, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=48, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=52, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=53, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=54, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=58, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=60, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=62, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=63, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=64, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=65, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=66, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=69, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=70, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=71, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=72, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=83, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=86, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=93, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=103, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=110, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=119, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=127, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=128, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=130, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=137, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=145, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=186, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=188, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=212, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=223, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=246, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=253, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=350, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=8, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=16, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=21, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=22, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=31, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=32, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=33, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=34, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=35, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=36, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=37, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=43, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=45, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=49, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=50, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=56, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=57, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=59, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=61, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=67, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=68, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=73, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=75, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=76, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=78, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=79, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=80, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=81, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=85, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=87, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=90, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=91, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=92, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=94, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=96, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=97, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=98, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=99, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=101, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=104, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=109, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=111, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=113, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=114, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=117, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=118, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=122, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=123, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=124, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=125, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=129, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=134, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=135, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=138, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=140, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=142, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=144, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=146, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=147, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=153, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=156, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=158, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=161, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=162, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=165, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=166, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=167, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=168, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=171, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=172, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=174, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=177, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=179, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=181, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=182, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=184, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=185, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=187, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=196, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=207, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=209, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=211, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=213, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=215, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=219, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=224, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=232, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=234, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=235, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=236, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=240, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=241, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=242, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=244, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=249, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=251, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=267, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=271, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=273, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=284, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=295, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=296, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=298, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=301, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=306, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=307, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=308, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=312, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=331, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=334, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=352, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=356, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=360, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=368, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=376, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=385, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=397, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=407, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=413, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=419, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=423, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=459, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=493, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=497, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=500, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=520, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=540, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=675, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=29, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=44, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=46, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=51, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=55, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=74, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=77, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=82, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=84, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=88, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=89, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=95, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=100, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=102, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=105, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=106, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=107, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=108, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=112, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=115, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=116, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=121, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=126, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=131, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=132, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=136, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=139, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=143, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=148, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=149, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=150, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=151, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=152, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=155, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=157, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=159, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=160, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=163, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=164, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=169, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=170, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=173, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=175, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=176, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=178, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=180, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=190, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=191, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=192, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=193, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=194, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=195, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=198, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=199, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=200, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=201, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=202, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=203, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=204, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=205, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=206, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=208, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=210, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=214, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=216, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=217, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=220, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=221, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=222, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=225, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=226, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=227, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=229, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=230, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=231, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=233, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=237, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=238, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=239, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=243, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=245, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=247, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=252, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=254, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=255, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=256, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=257, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=259, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=260, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=261, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=262, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=263, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=264, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=265, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=268, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=269, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=274, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=275, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=276, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=277, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=278, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=279, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=281, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=283, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=285, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=286, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=287, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=288, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=289, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=290, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=291, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=294, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=297, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=299, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=300, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=302, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=303, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=304, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=309, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=310, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=311, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=313, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=314, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=315, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=317, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=319, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=320, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=322, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=323, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=324, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=325, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=327, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=328, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=329, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=330, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=336, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=337, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=339, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=340, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=342, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=344, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=346, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=347, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=348, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=349, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=353, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=354, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=355, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=358, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=359, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=361, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=363, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=366, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=369, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=370, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=372, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=374, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=375, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=377, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=378, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=379, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=380, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=381, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=382, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=383, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=386, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=388, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=390, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=391, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=396, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=398, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=399, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=400, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=402, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=403, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=404, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=406, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=408, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=409, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=410, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=412, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=415, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=416, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=420, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=421, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=424, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=425, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=427, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=428, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=430, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=433, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=434, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=435, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=436, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=437, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=438, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=440, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=442, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=443, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=446, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=447, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=448, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=449, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=450, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=452, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=453, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=455, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=456, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=457, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=458, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=460, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=463, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=465, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=466, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=469, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=470, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=472, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=474, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=476, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=478, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=479, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=480, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=481, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=485, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=488, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=489, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=490, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=491, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=492, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=494, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=501, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=504, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=505, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=507, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=508, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=509, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=510, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=511, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=516, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=517, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=519, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=521, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=524, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=525, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=526, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=527, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=528, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=529, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=530, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=531, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=535, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=536, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=541, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=542, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=543, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=544, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=546, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=549, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=550, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=552, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=554, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=555, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=560, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=562, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=571, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=572, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=579, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=582, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=583, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=585, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=586, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=589, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=591, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=592, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=598, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=599, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=601, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=603, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=604, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=608, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=612, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=615, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=616, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=617, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=618, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=622, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=624, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=625, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=629, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=630, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=632, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=635, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=636, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=642, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=648, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=652, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=653, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=654, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=655, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=657, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=659, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=660, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=661, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=664, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=665, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=666, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=667, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=668, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=671, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=676, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=677, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=678, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=680, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=681, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
# ...
#  Row(SERIES_ID=817, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=820, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=822, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=823, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=824, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=826, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=829, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=832, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=835, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=836, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=837, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=838, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=839, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=841, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=843, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=845, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=846, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=847, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=848, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=850, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=851, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=854, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=856, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=857, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=861, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=865, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=867, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=869, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=870, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=874, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=875, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=876, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=877, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=880, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=883, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=885, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=887, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=889, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=890, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=891, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=893, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=894, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=896, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=897, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=900, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=901, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=902, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=903, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=904, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=905, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=906, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=909, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=913, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=914, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=916, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=917, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=918, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=919, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=920, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=922, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=924, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=925, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=930, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=931, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=932, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=933, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=934, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=936, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=937, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=938, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=939, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=940, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=943, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=944, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=945, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=949, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=950, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=954, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=955, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=960, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=961, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=964, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=965, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=966, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=967, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=969, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=970, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=972, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=975, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=977, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=978, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=979, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=980, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=982, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=983, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=985, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=986, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=987, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=990, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=991, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=992, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=993, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=995, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=997, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=999, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=183, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=189, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=395, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=422, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=444, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=502, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=512, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=532, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=567, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=584, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=596, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=602, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=610, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=613, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=645, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=646, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=647, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=663, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=670, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=672, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=750, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=758, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=773, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=779, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=780, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=786, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=790, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=798, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=803, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=813, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=825, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=834, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=840, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=842, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=853, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=859, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=863, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=866, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=873, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=878, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=881, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=884, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=886, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=927, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=928, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=929, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=935, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=941, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=951, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=952, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=956, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=958, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=959, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=962, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=971, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=981, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=989, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=996, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=699, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=764, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=830, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=855, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8)),
#  Row(SERIES_ID=898, MIN(DATE)=datetime.date(2018, 1, 1), MAX(DATE)=datetime.date(2023, 8, 8))]

# %%
sdf_raw.limit(5).to_pandas()
# Out:
#          DATE  SERIES_ID  VALUE
# 0  2018-01-01          1    119
# 1  2018-01-02          1    138
# 2  2018-01-03          1    134
# 3  2018-01-04          1    124
# 4  2018-01-05          1    103

# %%
sdf_raw.describe().collect()
# Out:
# [Row(SUMMARY='count', PUMP_ID=2046000.0, VALUE=2046000.0),
#  Row(SUMMARY='mean', PUMP_ID=500.5, VALUE=124.109512),
#  Row(SUMMARY='stddev', PUMP_ID=288.67506080366553, VALUE=35.57537708865502),
#  Row(SUMMARY='min', PUMP_ID=1.0, VALUE=44.0),
#  Row(SUMMARY='max', PUMP_ID=1000.0, VALUE=246.0)]

# %% [markdown]
# # Local Testing

# %%
df_data = sdf_raw.filter((F.col("SERIES_ID") == 62)).to_pandas()

# Here onwards copy paste in UDTF
df_data['DATE'] = pd.to_datetime(df_data['DATE'])
df_data.groupby('DATE').sum('VALUE').reset_index()
# df_data = df_data[['DATE','VALUE']]
df_data = df_data.sort_values(by=['DATE']).reset_index(drop=True)

# %%
df_data.head()
# Out:
#         DATE  SERIES_ID  VALUE
# 0 2018-01-01         62    119
# 1 2018-01-02         62    138
# 2 2018-01-03         62    133
# 3 2018-01-04         62    124
# 4 2018-01-05         62    103

# %%
df_data.set_index('DATE')['VALUE'].plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# ### Testing with Nixtla MLForecast

# %%
df_mlf = df_data.copy()
df_mlf.columns = ['ds', 'unique_id', 'y']
df_mlf.tail(5)
# Out:
#              ds  unique_id    y
# 2041 2023-08-04         62  161
# 2042 2023-08-05         62  153
# 2043 2023-08-06         62  158
# 2044 2023-08-07         62  176
# 2045 2023-08-08         62  192

# %%
from mlforecast import MLForecast
from mlforecast.target_transforms import Differences
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
XGBRegressor()
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
fh = 20

# %%
fcst = MLForecast(
    models=[LinearRegression(),XGBRegressor()],
    freq='D',  # our serie has a monthly frequency
    lags=[1,7,28,60],
    target_transforms=[Differences([1])],
)
fcst.fit(df_mlf.iloc[0:-fh])
# Out:
# MLForecast(models=[LinearRegression, XGBRegressor], freq=D, lag_features=['lag1', 'lag7', 'lag28', 'lag60'], date_features=[], num_threads=1)

# %%
preds = fcst.predict(fh)
preds
# Out:
#     unique_id         ds  LinearRegression  XGBRegressor
# 0          62 2023-07-20        194.852997    212.466034
# 1          62 2023-07-21        172.996307    198.135803
# 2          62 2023-07-22        160.601990    178.658844
# 3          62 2023-07-23        165.297745    163.765686
# 4          62 2023-07-24        183.210175    168.835663
# 5          62 2023-07-25        197.749863    185.528000
# 6          62 2023-07-26        208.514130    203.922455
# 7          62 2023-07-27        197.651093    209.769196
# 8          62 2023-07-28        175.647461    196.398132
# 9          62 2023-07-29        159.761337    175.942459
# 10         62 2023-07-30        164.983032    162.735489
# 11         62 2023-07-31        185.443756    166.507584
# 12         62 2023-08-01        198.783829    187.490997
# 13         62 2023-08-02        206.167542    206.295059
# 14         62 2023-08-03        196.293457    210.199280
# 15         62 2023-08-04        174.787521    197.353470
# 16         62 2023-08-05        161.678528    176.738632
# 17         62 2023-08-06        167.845413    165.443802
# 18         62 2023-08-07        184.928024    167.816864
# 19         62 2023-08-08        202.231384    189.156616

# %%
df_res = preds.merge(df_mlf, left_on=['ds','unique_id'], right_on = ['ds','unique_id'],how='left')
df_res = df_res.drop('unique_id', axis=1)

# %%
df = df_res.copy()
df.set_index('ds', inplace=True)

# Plotting the time series
plt.figure(figsize=(10, 6))

plt.plot(df.index, df['LinearRegression'], label='Linear Regression')
plt.plot(df.index, df['XGBRegressor'], label='XGB Regressor')
plt.plot(df.index, df['y'], label='Actual Values')

# Adding title and labels
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('Values')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### Testing with Sktime Locally

# %%
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.theta import ThetaForecaster
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error

# %%
df_input = pd.Series(df_data['VALUE'].values, index=df_data['TIMESTAMP'])
df_input
# Out:
# TIMESTAMP
# 2018-01-01    119
# 2018-01-02    138
# 2018-01-03    133
# 2018-01-04    124
# 2018-01-05    103
#              ...
# 2023-08-04    161
# 2023-08-05    153
# 2023-08-06    158
# 2023-08-07    176
# 2023-08-08    192
# Length: 2046, dtype: int16

# %%
df_input.index.freq = 'D'  # Set this to the appropriate frequency
df_input = df_input.resample('D').asfreq()  # Resample if needed; adjust the 'M' if using a different frequency

# %%
y_train, y_test = temporal_train_test_split(df_input)
fh = ForecastingHorizon(y_test.index, is_relative=False)
forecaster = ThetaForecaster(sp=12)  # monthly seasonal periodicity
forecaster.fit(y_train)
y_pred = forecaster.predict(fh)
y_pred
# Out:
# TIMESTAMP
# 2022-03-15    166.037887
# 2022-03-16    166.349381
# 2022-03-17    165.784103
# 2022-03-18    165.128814
# 2022-03-19    165.061084
#                  ...
# 2023-08-04    172.499784
# 2023-08-05    172.428377
# 2023-08-06    172.944889
# 2023-08-07    174.079407
# 2023-08-08    173.627253
# Freq: D, Length: 512, dtype: float64

# %%
y_pred = forecaster.predict(fh)
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.0888130877494323

# %% [markdown]
# ### Testing with Dart Locally

# %%
# !pip install darts

# %%
import darts
from darts import TimeSeries
from darts.models import FFT
from darts.metrics import mae, mape
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# Train + Forecast Length
train_length = 600
forecast_horizon = 30
train_end = max(df_data['TIMESTAMP']) - pd.Timedelta(days = 30)
train_start = train_end - pd.Timedelta(days = 600)
df_input = df_data.loc[(df_data['TIMESTAMP'] >= train_start) &
                        (df_data['TIMESTAMP'] < train_end)].reset_index(drop=True)
df_input = df_input.set_index('TIMESTAMP')
df_input.index.name = 'time'

ts_train = TimeSeries.from_dataframe(df_input, fill_missing_dates=True, freq='D')
ts_train
# Out:
# <TimeSeries (DataArray) (time: 600, component: 1, sample: 1)>
# array([[[184.]],
#
#        [[184.]],
#
#        [[170.]],
#
#        [[149.]],
#
#        [[133.]],
#
#        [[141.]],
#
#        [[155.]],
#
#        [[174.]],
#
#        [[184.]],
#
#        [[174.]],
#
# ...
#
#        [[194.]],
#
#        [[173.]],
#
#        [[150.]],
#
#        [[154.]],
#
#        [[177.]],
#
#        [[190.]],
#
#        [[196.]],
#
#        [[185.]],
#
#        [[167.]],
#
#        [[156.]]])
# Coordinates:
#   * time       (time) datetime64[ns] 2021-11-16 2021-11-17 ... 2023-07-08
#   * component  (component) object 'VALUE'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
from darts.models import XGBModel
my_model = XGBModel(lags = 10, n_estimators=100, max_depth=5)
my_model.fit(ts_train)
# Out:
# XGBModel(lags=10, lags_past_covariates=None, lags_future_covariates=None, output_chunk_length=1, add_encoders=None, likelihood=None, quantiles=None, random_state=None, multi_models=True, use_static_covariates=True, n_estimators=100, max_depth=5)

# %%
ts_forecast = my_model.predict(forecast_horizon)
data = ts_forecast.pd_dataframe().reset_index().values
df_forecasted = pd.DataFrame(data, columns = ['TIMESTAMP','FORECAST'])
df_forecasted
# Out:
#     TIMESTAMP    FORECAST
# 0  2023-07-09  154.098129
# 1  2023-07-10  177.000229
# 2  2023-07-11  194.219437
# 3  2023-07-12  196.041092
# 4  2023-07-13  178.886414
# 5  2023-07-14  167.056152
# 6  2023-07-15  153.515213
# 7  2023-07-16  153.075653
# 8  2023-07-17  177.338379
# 9  2023-07-18  195.800369
# 10 2023-07-19  194.430466
# 11 2023-07-20  184.703201
# 12 2023-07-21  166.946381
# 13 2023-07-22  154.664413
# 14 2023-07-23  153.762146
# 15 2023-07-24  176.461807
# 16 2023-07-25  195.846237
# 17 2023-07-26  196.354233
# 18 2023-07-27  181.805481
# 19 2023-07-28  167.864731
# 20 2023-07-29  152.877487
# 21 2023-07-30  155.224548
# 22 2023-07-31  175.632339
# 23 2023-08-01  195.348694
# 24 2023-08-02  198.228134
# 25 2023-08-03  184.869492
# 26 2023-08-04  166.549332
# 27 2023-08-05  153.542572
# 28 2023-08-06  155.645676
# 29 2023-08-07  176.744888

# %%
df_compare = df_data.merge(df_forecasted, how='left', left_on='TIMESTAMP', right_on='TIMESTAMP')
df_compare = df_compare.set_index('TIMESTAMP')
df_compare.iloc[-90:].plot()
# Out:
# <Axes: xlabel='TIMESTAMP'>

# %%
df_res = df_compare.dropna()
df_res = (df_res['VALUE'] - df_res['FORECAST'])/df_res['VALUE'] * 100
print('MAPE= ',df_res.mean())
# Out:
# MAPE=  1.5275283859880622

# %% [markdown]
# # Creating UDTF for multi-node parallelized model training

# %%
schema = T.StructType([
    T.StructField("ID", T.IntegerType()),
    T.StructField("TIMESTAMP", T.DateType()),
    T.StructField("LINREG", T.FloatType()),
    T.StructField("XGB", T.FloatType()),
    T.StructField("TRAIN_START", T.DateType()),
    T.StructField("TRAIN_END", T.DateType()),
    T.StructField("FORECAST_HORIZON", T.IntegerType())
                  ])

@F.udtf(output_schema = schema,
        input_types = [T.VariantType()],
        name = "TSF_MLFORECAST", is_permanent=True, stage_location= "@DEMO_DB.PUBLIC.ML_MODELS", session=session,
        packages=['pandas', 'mlforecast' ,'xgboost', 'scikit-learn'],
        replace=True
       )

class forecast:
    def __init__(self):
        self.rows=[]
        self.dfs=[]
    
    def process(self, data):
        self.rows.append(data)

        # Merge rows into a dataframe
        if len(self.rows) >= 16000:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []
        
        # Merge dataframes into a single dataframe
        # Minimizes memory footprint
        if len(self.dfs) >= 100:
            merged_df = pd.concat(self.dfs)
            self.dfs = [merged_df]

        yield None
    
    def end_partition(self):
        # Merge any remaining rows
        from mlforecast import MLForecast
        from mlforecast.target_transforms import Differences
        from xgboost import XGBRegressor
        from sklearn.linear_model import LinearRegression

        if len(self.rows) > 0:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []

        # Process Input
        df_input = pd.concat(self.dfs)
        df_input['DATE'] = pd.to_datetime(df_input['DATE'])
        df_input.groupby(['DATE','SERIES_ID']).sum('VALUE').reset_index()
        df_input = df_input[['DATE','SERIES_ID','VALUE']]
        df_input.columns = ['ds','unique_id','y']

        #Train + Forecast Length
        train_length = 600
        fh = 30 # Forecast Horizon
        train_end = max(df_input['ds'])
        train_start = train_end - pd.Timedelta(days = 600)
        
        df_input = df_input.loc[(df_input['ds'] >= train_start) &
                                (df_input['ds'] < train_end)].reset_index(drop=True)

        
        fcst = MLForecast(models=[LinearRegression(),XGBRegressor()],
                          freq='D',
                          lags=[1,7,28,60],
                          target_transforms=[Differences([1])])
        
        fcst.fit(df_mlf.iloc[0:-fh])

        ts_forecast = fcst.predict(fh)
        
        # Processing
        ts_forecast.columns = ['ID','TIMESTAMP','LINREG','XGB']
        ts_forecast['TRAIN_START'] = train_start
        ts_forecast['TRAIN_END'] = train_end
        ts_forecast['FORECAST_HORIZON'] = fh

        yield from ts_forecast.itertuples(index=False, name=None)
# Out:
# The version of package 'mlforecast' in the local environment is 0.11.2, which does not fit the criteria for the requirement 'mlforecast'. Your UDF might not work when the package version is different between the server and your local environment.

# %%
sdf_raw.limit(5).to_pandas()
# Out:
#          DATE  SERIES_ID  VALUE
# 0  2018-01-01          1    119
# 1  2018-01-02          1    138
# 2  2018-01-03          1    134
# 3  2018-01-04          1    124
# 4  2018-01-05          1    103

# %%
df = session.table('TIME_SERIES') \
        .with_column('ROW', F.object_construct_keep_null('*')) \
        .select(F.col('SERIES_ID'), F.col('ROW'))

store_forecast_test = F.table_function("TSF_MLFORECAST")

variant_column = F.parse_json(df.col('ROW').cast(T.VariantType()))

forecast = df.select(
                F.col('SERIES_ID'), 
                store_forecast_test(variant_column).over(partition_by=['SERIES_ID'])
                )

forecast = forecast.with_column('FORECAST_DATETIME', F.current_timestamp())
forecast.write.save_as_table("DEMO_DB.PUBLIC.FORECAST_USING_MLFORECAST", mode="append")

# %%
sdf_ref = session.table('DEMO_DB.PUBLIC.FORECAST_USING_MLFORECAST')
sdf_ref.limit(5).to_pandas()
# Out:
#    SERIES_ID  ID   TIMESTAMP      LINREG         XGB TRAIN_START   TRAIN_END  \
# 0        711  62  2023-07-10  177.673706  178.250305  2021-12-16  2023-08-08
# 1        711  62  2023-07-11  197.565735  196.981827  2021-12-16  2023-08-08
# 2        711  62  2023-07-12  200.064362  199.370331  2021-12-16  2023-08-08
# 3        711  62  2023-07-13  187.862564  188.086197  2021-12-16  2023-08-08
# 4        711  62  2023-07-14  169.951813  166.865524  2021-12-16  2023-08-08
#
#    FORECAST_HORIZON                FORECAST_DATETIME
# 0                30 2023-12-11 23:04:37.098000-08:00
# 1                30 2023-12-11 23:04:37.098000-08:00
# 2                30 2023-12-11 23:04:37.098000-08:00
# 3                30 2023-12-11 23:04:37.098000-08:00
# 4                30 2023-12-11 23:04:37.098000-08:00

# %% [markdown]
# ### Upload library to Snowflake Stage
# We are uploading to a stage as this library is not available through the Snowflake Anaconda Channel.

# %%
import nfoursid
nfoursid_path = nfoursid.__path__[0]
print(nfoursid_path)

# %%
import darts
darts_path = darts.__path__[0]
print(darts_path)
# Out:
# /Users/skhara/anaconda3/envs/pysnowpark_ml_09_2023/lib/python3.9/site-packages/darts

# %%
zip_file_path = "/Users/skhara/anaconda3/envs/pysnowpark_ml_tpcds/lib/python3.9/site-packages/nfoursid.zip"
session.file.put(zip_file_path, "@ML_MODELS", auto_compress=False, overwrite=True)

# %%
zip_file_path = "/Users/skhara/anaconda3/envs/pysnowpark_ml_tpcds/lib/python3.9/site-packages/darts.zip"
session.file.put(zip_file_path, "@ML_MODELS", auto_compress=False, overwrite=True)

# %%
schema = T.StructType([
    T.StructField("TIMESTAMP", T.DateType()),
    T.StructField("FORECAST", T.IntegerType()),
    T.StructField("TRAIN_START", T.DateType()),
    T.StructField("TRAIN_END", T.DateType()),
    T.StructField("FORECAST_HORIZON", T.IntegerType())
])

@F.udtf(output_schema = schema,
        input_types = [T.VariantType()],
        name = "PUMP_TS_DARTS_RANDOMFOREST", is_permanent=True, stage_location="@ML_MODELS", session=session,
        packages=['pandas', 'fsspec==2023.4.0','holidays==0.18',
                  'joblib==1.2.0','lightning-utilities==0.7.1','matplotlib==3.7.1',
                  'plotly==5.9.0','pmdarima==2.0.3','pytorch==2.0.1',
                  'pytorch-lightning==2.0.3','pyyaml==6.0','scikit-learn==1.2.2',
                  'scipy==1.10.1','snowflake-snowpark-python==1.4.0','statsmodels',
                  'tbats==1.1.3','torchmetrics==0.11.4','tqdm','xarray'
                 ], replace=True,
        imports = ["@ML_MODELS/nfoursid.zip", "@ML_MODELS/darts.zip"])

class forecast:
    def __init__(self):
        self.rows=[]
        self.dfs=[]
    
    def process(self, data):
        self.rows.append(data)

        # Merge rows into a dataframe
        if len(self.rows) >= 16000:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []
        
        # Merge dataframes into a single dataframe
        # Minimizes memory footprint
        if len(self.dfs) >= 100:
            merged_df = pd.concat(self.dfs)
            self.dfs = [merged_df]

        yield None
    
    def end_partition(self):
        # Merge any remaining rows
        from darts import TimeSeries
        from darts.models import RandomForest

        if len(self.rows) > 0:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []
        
        # Process Input
        df_input = pd.concat(self.dfs)
        df_input['TIMESTAMP'] = pd.to_datetime(df_input['TIMESTAMP'])
        df_input = df_input.groupby('TIMESTAMP').sum('VALUE').reset_index()
        df_input = df_input[['TIMESTAMP','VALUE']]

        #Train + Forecast Length
        train_length = 600
        forecast_horizon = 30
        train_end = max(df_input['TIMESTAMP'])
        train_start = train_end - pd.Timedelta(days = 600)
        
        df_input = df_input.loc[(df_input['TIMESTAMP'] >= train_start) &
                                (df_input['TIMESTAMP'] < train_end)].reset_index(drop=True)
        df_input = df_input.set_index('TIMESTAMP')
        df_input.index.name = 'time'
        
        # Convert DataFrame to Darts TS Object
        ts_train = TimeSeries.from_dataframe(df_input, fill_missing_dates=True, freq='D')
        
        # Initialize Model
        my_model = RandomForest(lags = 10, n_estimators=100, max_depth=5)

        # Fit Model and Predict
        my_model.fit(ts_train)
        ts_forecast = my_model.predict(forecast_horizon)
        
        # Processing
        data = ts_forecast.pd_dataframe().reset_index().values
        df_forecast = pd.DataFrame(data, columns = ['TIMESTAMP','VALUE'])
        df_forecast['TRAIN_START'] = train_start
        df_forecast['TRAIN_END'] = train_end
        df_forecast['FORECAST_HORIZON'] = forecast_horizon

        yield from df_forecast.itertuples(index=False, name=None)
# Out:
# The version of package 'fsspec' in the local environment is 2023.9.2, which does not fit the criteria for the requirement 'fsspec==2023.4.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'holidays' in the local environment is 0.33, which does not fit the criteria for the requirement 'holidays==0.18'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'joblib' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'joblib==1.2.0'. Your UDF might not work when the package version is different between the server and your local environment.
# Package 'plotly' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.
# Package 'pytorch' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.
# The version of package 'pytorch-lightning' in the local environment is 2.0.9.post0, which does not fit the criteria for the requirement 'pytorch-lightning==2.0.3'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'pyyaml' in the local environment is 6.0.1, which does not fit the criteria for the requirement 'pyyaml==6.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'snowflake-snowpark-python' in the local environment is 1.7.0a2, which does not fit the criteria for the requirement 'snowflake-snowpark-python==1.4.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'torchmetrics' in the local environment is 1.2.0, which does not fit the criteria for the requirement 'torchmetrics==0.11.4'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'tqdm' in the local environment is 4.66.1, which does not fit the criteria for the requirement 'tqdm'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'xarray' in the local environment is 2023.9.0, which does not fit the criteria for the requirement 'xarray'. Your UDF might not work when the package version is different between the server and your local environment.

# %%
df = session.table('TIME_SERIES_DATA') \
        .with_column('ROW', F.object_construct_keep_null('*')) \
        .select(F.col('PUMP_ID'), F.col('ROW'))

store_forecast_test = F.table_function("PUMP_TS_DARTS_RANDOMFOREST")

variant_column = F.parse_json(df.col('ROW').cast(T.VariantType()))

forecast = df.select(
                F.col('PUMP_ID'),
                F.col('GENDER')
                store_forecast_test(variant_column).over(partition_by=['PUMP_ID','GENDER'])
                )

forecast = forecast.with_column('MODEL', F.lit('RANDOMFOREST'))
forecast = forecast.with_column('FORECAST_DATETIME', F.current_timestamp())
forecast.write.save_as_table("FORECAST_USING_DARTS_RANDOMFOREST", mode="overwrite")

# %%
df_temp = session.table('FORECAST_USING_DARTS_RANDOMFOREST')
df_temp.limit(5).to_pandas()
# Out:
#    PUMP_ID   TIMESTAMP  FORECAST TRAIN_START   TRAIN_END  FORECAST_HORIZON  \
# 0      688  2023-08-08       171  2021-12-16  2023-08-08                30
# 1      688  2023-08-09       175  2021-12-16  2023-08-08                30
# 2      688  2023-08-10       162  2021-12-16  2023-08-08                30
# 3      688  2023-08-11       143  2021-12-16  2023-08-08                30
# 4      688  2023-08-12       134  2021-12-16  2023-08-08                30
#
#           MODEL                FORECAST_DATETIME
# 0  RANDOMFOREST 2023-10-02 12:31:12.922000-07:00
# 1  RANDOMFOREST 2023-10-02 12:31:12.922000-07:00
# 2  RANDOMFOREST 2023-10-02 12:31:12.922000-07:00
# 3  RANDOMFOREST 2023-10-02 12:31:12.922000-07:00
# 4  RANDOMFOREST 2023-10-02 12:31:12.922000-07:00

# %%
schema = T.StructType([
    T.StructField("TIMESTAMP", T.DateType()),
    T.StructField("FORECAST", T.IntegerType()),
    T.StructField("TRAIN_START", T.DateType()),
    T.StructField("TRAIN_END", T.DateType()),
    T.StructField("FORECAST_HORIZON", T.IntegerType())
])

@F.udtf(output_schema = schema,
        input_types = [T.VariantType()],
        name = "PUMP_TS_DARTS_FFT", is_permanent=True, stage_location="@ML_MODELS", session=session,
        packages=['pandas', 'fsspec==2023.4.0','holidays==0.18',
                  'joblib==1.2.0','lightning-utilities==0.7.1','matplotlib==3.7.1',
                  'plotly==5.9.0','pmdarima==2.0.3','pytorch==2.0.1',
                  'pytorch-lightning==2.0.3','pyyaml==6.0','scikit-learn==1.2.2',
                  'scipy==1.10.1','snowflake-snowpark-python==1.4.0','statsmodels',
                  'tbats==1.1.3','torchmetrics==0.11.4','tqdm','xarray'
                 ], replace=True,
        imports = ["@ML_MODELS/nfoursid.zip", "@ML_MODELS/darts.zip"])

class forecast:
    def __init__(self):
        self.rows=[]
        self.dfs=[]
    
    def process(self, data):
        self.rows.append(data)

        # Merge rows into a dataframe
        if len(self.rows) >= 16000:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []
        
        # Merge dataframes into a single dataframe
        # Minimizes memory footprint
        if len(self.dfs) >= 100:
            merged_df = pd.concat(self.dfs)
            self.dfs = [merged_df]

        yield None
    
    def end_partition(self):
        # Merge any remaining rows
        from darts import TimeSeries
        from darts.models import FFT

        if len(self.rows) > 0:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []
        
        # Process Input
        df_input = pd.concat(self.dfs)
        df_input['TIMESTAMP'] = pd.to_datetime(df_input['TIMESTAMP'])
        df_input.groupby('TIMESTAMP').sum('VALUE').reset_index()
        df_input = df_input[['TIMESTAMP','VALUE']]

        #Train + Forecast Length
        train_length = 600
        forecast_horizon = 30
        train_end = max(df_input['TIMESTAMP'])
        train_start = train_end - pd.Timedelta(days = 600)
        
        df_input = df_input.loc[(df_input['TIMESTAMP'] >= train_start) &
                                (df_input['TIMESTAMP'] < train_end)].reset_index(drop=True)
        df_input = df_input.set_index('TIMESTAMP')
        df_input.index.name = 'time'
        
        # Convert DataFrame to Darts TS Object
        ts_train = TimeSeries.from_dataframe(df_input, fill_missing_dates=True, freq='D')
        
        # Initialize Model
        FFT_model = FFT(nr_freqs_to_keep=400,trend=None)
        
        # Fit Model and Predict
        FFT_model.fit(ts_train)
        ts_forecast = FFT_model.predict(forecast_horizon)
        
        # Processing
        data = ts_forecast.pd_dataframe().reset_index().values
        df_forecast = pd.DataFrame(data, columns = ['TIMESTAMP','VALUE'])
        df_forecast['TRAIN_START'] = train_start
        df_forecast['TRAIN_END'] = train_end
        df_forecast['FORECAST_HORIZON'] = forecast_horizon

        yield from df_forecast.itertuples(index=False, name=None)
# Out:
# The version of package 'fsspec' in the local environment is 2023.9.0, which does not fit the criteria for the requirement 'fsspec==2023.4.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'holidays' in the local environment is 0.32, which does not fit the criteria for the requirement 'holidays==0.18'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'joblib' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'joblib==1.2.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'lightning-utilities' in the local environment is 0.9.0, which does not fit the criteria for the requirement 'lightning-utilities==0.7.1'. Your UDF might not work when the package version is different between the server and your local environment.
# Package 'plotly' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.
# Package 'pytorch' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.
# The version of package 'pytorch-lightning' in the local environment is 2.0.9, which does not fit the criteria for the requirement 'pytorch-lightning==2.0.3'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'pyyaml' in the local environment is 6.0.1, which does not fit the criteria for the requirement 'pyyaml==6.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'snowflake-snowpark-python' in the local environment is 1.7.0, which does not fit the criteria for the requirement 'snowflake-snowpark-python==1.4.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'torchmetrics' in the local environment is 1.1.2, which does not fit the criteria for the requirement 'torchmetrics==0.11.4'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'tqdm' in the local environment is 4.66.1, which does not fit the criteria for the requirement 'tqdm'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'xarray' in the local environment is 2023.8.0, which does not fit the criteria for the requirement 'xarray'. Your UDF might not work when the package version is different between the server and your local environment.

# %%
df = session.table('TIME_SERIES_DATA') \
        .with_column('ROW', F.object_construct_keep_null('*')) \
        .select(F.col('PUMP_ID'), F.col('ROW'))

store_forecast_test = F.table_function("PUMP_TS_DARTS_FFT")

variant_column = F.parse_json(df.col('ROW').cast(T.VariantType()))

forecast = df.select(
                F.col('PUMP_ID'), 
                store_forecast_test(variant_column).over(partition_by=['PUMP_ID'])
                )

forecast = forecast.with_column('MODEL', F.lit('FFT'))
forecast = forecast.with_column('FORECAST_DATETIME', F.current_timestamp())
forecast.write.save_as_table("FORECAST_USING_DARTS_FFT", mode="overwrite")

# %%
df_temp = session.table('FORECAST_USING_DARTS_FFT')
df_temp.limit(5).to_pandas()
# Out:
#    PUMP_ID   TIMESTAMP  FORECAST TRAIN_START   TRAIN_END  FORECAST_HORIZON  \
# 0      937  2023-08-08       174  2021-12-16  2023-08-08                30
# 1      937  2023-08-09       153  2021-12-16  2023-08-08                30
# 2      937  2023-08-10       141  2021-12-16  2023-08-08                30
# 3      937  2023-08-11       142  2021-12-16  2023-08-08                30
# 4      937  2023-08-12       164  2021-12-16  2023-08-08                30
#
#   MODEL                FORECAST_DATETIME
# 0   FFT 2023-09-15 07:40:16.789000-07:00
# 1   FFT 2023-09-15 07:40:16.789000-07:00
# 2   FFT 2023-09-15 07:40:16.789000-07:00
# 3   FFT 2023-09-15 07:40:16.789000-07:00
# 4   FFT 2023-09-15 07:40:16.789000-07:00

# %% [markdown]
# ## - Darts with XGBoost

# %%
schema = T.StructType([
    T.StructField("TIMESTAMP", T.DateType()),
    T.StructField("FORECAST", T.IntegerType()),
    T.StructField("TRAIN_START", T.DateType()),
    T.StructField("TRAIN_END", T.DateType()),
    T.StructField("FORECAST_HORIZON", T.IntegerType())
])

@F.udtf(output_schema = schema,
        input_types = [T.VariantType()],
        name = "PUMP_TS_DARTS_XGB", is_permanent=True, stage_location="@ML_MODELS", session=session,
        packages=['pandas', 'fsspec==2023.4.0','holidays==0.18',
                  'joblib==1.2.0','lightning-utilities==0.7.1','matplotlib==3.7.1',
                  'plotly==5.9.0','pmdarima==2.0.3','pytorch==2.0.1',
                  'pytorch-lightning==2.0.3','pyyaml==6.0','scikit-learn==1.2.2',
                  'scipy==1.10.1','snowflake-snowpark-python==1.4.0','statsmodels',
                  'tbats==1.1.3','torchmetrics==0.11.4','tqdm','xarray','xgboost'
                 ], replace=True,
        imports = ["@ML_MODELS/nfoursid.zip", "@ML_MODELS/darts.zip"])

class forecast:
    def __init__(self):
        self.rows=[]
        self.dfs=[]
    
    def process(self, data):
        self.rows.append(data)

        # Merge rows into a dataframe
        if len(self.rows) >= 16000:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []
        
        # Merge dataframes into a single dataframe
        # Minimizes memory footprint
        if len(self.dfs) >= 100:
            merged_df = pd.concat(self.dfs)
            self.dfs = [merged_df]

        yield None
    
    def end_partition(self):
        # Merge any remaining rows
        from darts import TimeSeries
        import xgboost
        from darts.models import XGBModel
        

        if len(self.rows) > 0:
            df = pd.DataFrame(self.rows)
            self.dfs.append(df)
            self.rows = []
        
        # Process Input
        df_input = pd.concat(self.dfs)
        df_input['TIMESTAMP'] = pd.to_datetime(df_input['TIMESTAMP'])
        df_input.groupby('TIMESTAMP').sum('VALUE').reset_index()
        df_input = df_input[['TIMESTAMP','VALUE']]

        #Train + Forecast Length
        train_length = 600
        forecast_horizon = 30
        train_end = max(df_input['TIMESTAMP'])
        train_start = train_end - pd.Timedelta(days = 600)
        
        df_input = df_input.loc[(df_input['TIMESTAMP'] >= train_start) &
                                (df_input['TIMESTAMP'] < train_end)].reset_index(drop=True)
        df_input = df_input.set_index('TIMESTAMP')
        df_input.index.name = 'time'
        
        # Convert DataFrame to Darts TS Object
        ts_train = TimeSeries.from_dataframe(df_input, fill_missing_dates=True, freq='D')
        
        # Initialize Model
        my_model = XGBModel(lags = 10, n_estimators=100, max_depth=5)

        # Fit Model and Predict
        my_model.fit(ts_train)
        ts_forecast = my_model.predict(forecast_horizon)
        
        # Processing
        data = ts_forecast.pd_dataframe().reset_index().values
        df_forecast = pd.DataFrame(data, columns = ['TIMESTAMP','VALUE'])
        df_forecast['TRAIN_START'] = train_start
        df_forecast['TRAIN_END'] = train_end
        df_forecast['FORECAST_HORIZON'] = forecast_horizon

        yield from df_forecast.itertuples(index=False, name=None)
# Out:
# The version of package 'fsspec' in the local environment is 2023.9.0, which does not fit the criteria for the requirement 'fsspec==2023.4.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'holidays' in the local environment is 0.32, which does not fit the criteria for the requirement 'holidays==0.18'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'joblib' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'joblib==1.2.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'lightning-utilities' in the local environment is 0.9.0, which does not fit the criteria for the requirement 'lightning-utilities==0.7.1'. Your UDF might not work when the package version is different between the server and your local environment.
# Package 'plotly' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.
# Package 'pytorch' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.
# The version of package 'pytorch-lightning' in the local environment is 2.0.9, which does not fit the criteria for the requirement 'pytorch-lightning==2.0.3'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'pyyaml' in the local environment is 6.0.1, which does not fit the criteria for the requirement 'pyyaml==6.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'snowflake-snowpark-python' in the local environment is 1.7.0, which does not fit the criteria for the requirement 'snowflake-snowpark-python==1.4.0'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'torchmetrics' in the local environment is 1.1.2, which does not fit the criteria for the requirement 'torchmetrics==0.11.4'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'tqdm' in the local environment is 4.66.1, which does not fit the criteria for the requirement 'tqdm'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'xarray' in the local environment is 2023.8.0, which does not fit the criteria for the requirement 'xarray'. Your UDF might not work when the package version is different between the server and your local environment.

# %%
df = session.table('TIME_SERIES_DATA') \
        .with_column('ROW', F.object_construct_keep_null('*')) \
        .select(F.col('PUMP_ID'), F.col('ROW'))

store_forecast_test = F.table_function("PUMP_TS_DARTS_XGB")

variant_column = F.parse_json(df.col('ROW').cast(T.VariantType()))

forecast = df.select(
                F.col('PUMP_ID'), 
                store_forecast_test(variant_column).over(partition_by=['PUMP_ID'])
                )

forecast = forecast.with_column('MODEL', F.lit('XGB'))
forecast = forecast.with_column('FORECAST_DATETIME', F.current_timestamp())
forecast.write.save_as_table("FORECAST_USING_DARTS_XGB", mode="append")

# %%
# df_temp = session.table('FORECAST_USING_DARTS_XGB')
# df_temp.limit(5).to_pandas()

# %% [markdown]
# # Deployment
# Two options -
# 1. Create a task using SQL
# 2. Create a task using Task API (future improvement)
#
# The code given below uses option 1 to create a task in SQL.
# 1. Get the command to run the forecast function
# 2. Create a task
# 3. Resume task to run on the schedule

# %%
forecast_script = f'''
INSERT  INTO FORECAST_USING_DARTS_XGB  SELECT "PUMP_ID", "TIMESTAMP", "FORECAST", "TRAIN_START", "TRAIN_END",
"FORECAST_HORIZON", 'XGB' AS "MODEL", current_timestamp() AS "FORECAST_DATETIME"
FROM ( SELECT T_LEFT.*, T_RIGHT."TIMESTAMP", T_RIGHT."FORECAST", T_RIGHT."TRAIN_START", T_RIGHT."TRAIN_END", T_RIGHT."FORECAST_HORIZON"
FROM ( SELECT "PUMP_ID", object_construct_keep_null(*) AS "ROW" FROM TIME_SERIES_DATA) AS T_LEFT
JOIN  TABLE (PUMP_TS_DARTS_XGB(parse_json( CAST ("ROW" AS VARIANT)))  OVER (PARTITION BY "PUMP_ID" )) AS T_RIGHT)
'''

task_script = f'''
CREATE OR REPLACE TASK POC_INVISTA.TASK_FORECAST_TS
WAREHOUSE = SSK_RESEARCH
SCHEDULE = '1 MINUTE'
AS {forecast_script};
'''

resume_script = f'''ALTER TASK POC_INVISTA.TASK_FORECAST_TS RESUME;'''

# %%
session.sql(task_script).collect()
# session.sql(resume_script).collect()
# Out:
# [Row(status='Task TASK_FORECAST_TS successfully created.')]
